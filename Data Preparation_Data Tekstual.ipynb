# %% [markdown]
# # Data Preparation - Wikipedia Indonesia Text Data
#
# Notebook ini mendemonstrasikan proses data preparation pada data tekstual.
#
# ## Alur Proses:
# 1. **Load**: Membaca dan menjelajahi dataset awal
# 2. **Data Cleaning**: Membersihkan markup Wikipedia dan ekstrak kategori
# 3. **Pipeline Processing**: Menerapkan transformasi data secara bertahap
# 4. **Tokenization** : Memecah teks menjadi kunpulan token
# 5. **Vectorization**: Mengkonversi text menjadi TF-IDF matrix
# 6. **Search & Retrieval**: Mencari dokumen paling relevan dengan query

# %%
import pandas as pd
import re

# %% [markdown]
# ## 2. Load Dataset
#
# Membaca file CSV yang berisi data artikel Wikipedia Indonesia dalam format raw (mentah dengan markup Wiki masih ada).

# %%
#Membaca dataframe (file csv), dengan delimiter pipe (|)
df = pd.read_csv('wikipedia_raw.csv', delimiter = '|')

# %%
#menampilkan dataframe
df.head(5)
# Out:
#    Unnamed: 0  id             timestamp                   title  \
# 0           0   1  2022-04-24T00:35:51Z  Asam deoksiribonukleat
# 1           1   3  2022-05-05T11:26:32Z             Anwar Sadat
# 2           2   5  2022-09-26T04:25:33Z               Arkeologi
# 3           3   6  2022-11-02T02:33:49Z             Antropologi
# 4           4   8  2022-11-16T04:21:39Z        Bahasa Indonesia
#
#                                                 text
# 0  [[Berkas:DNA Structure+Key+Labelled.pn NoBB.pn...
# 1  '''Muhammad Anwar el-Sadat'''; ) adalah seoran...
# 2  [[Berkas:Bulgandry Aboriginal Site.JPG|jmpl|Si...
# 3  '''Antropologi''' adalah ilmu tentang manusia....
# 4  '''Bahasa Indonesia''' adalah [[bahasa nasiona...

# %%
#meilhat informasi umum dari dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86436 entries, 0 to 86435
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  86436 non-null  int64
#  1   id          86436 non-null  int64
#  2   timestamp   86436 non-null  object
#  3   title       86436 non-null  object
#  4   text        86436 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 3.3+ MB

# %% [markdown]
# #### Melihat contoh isi `teks`

# %%
#Menampilkan contoh isi data teks
print(df.loc[0,'text'])
# Out:
# [[Berkas:DNA Structure+Key+Labelled.pn NoBB.png|jmpl|ka|340px|Struktur [[heliks ganda]] DNA. [[Atom]]-atom pada struktur tersebut diwarnai sesuai dengan [[unsur kimia]]nya dan struktur detail dua pasangan basa ditunjukkan oleh gambar kanan bawah]]
# [[Berkas:DNA animation.gif|jmpl|Gambaran tiga dimensi DNA]]
# '''Asam deoksiribonukleat''', lebih dikenal dengan singkatan '''DNA''' ([[bahasa Inggris]]: '''''d'''eoxyribo'''n'''ucleic '''a'''cid''), adalah salah satu jenis [[asam nukleat]] yang memiliki kemampuan [[Hereditas|pewarisan]] sifat. Keberadaan asam deoksiribonukleat ditemukan di dalam [[nukleoprotein]] yang membentuk [[inti sel]]. [[James Dewey Watson]] dan [[Francis Crick]] merupakan ilmuwan pertama yang mengajukan model struktur DNA pada tahun 1953 dengan bentuk [[pilinan ganda]]. Setiap DNA tersusun dari dua buah rantai [[polinukleotida]].<ref></ref> DNA merupakan sejenis biomolekul yang menyimpan dan menyandi instruksi-instruksi [[genetika]] setiap [[organisme]] dan banyak jenis [[virus]]. Instruksi-instruksi genetika ini berperan penting dalam pertumbuhan, perkembangan, dan fungsi organisme dan virus. DNA merupakan [[asam nukleat]]; bersamaan dengan [[protein]] dan [[karbohidrat]], asam nukleat adalah [[makromolekul]] esensial bagi seluruh [[makhluk hidup]] yang diketahui. Kebanyakan molekul DNA terdiri dari dua unting [[biopolimer]] yang berpilin satu sama lainnya membentuk [[heliks ganda]]. Dua unting DNA ini dikenal sebagai [[polinukleotida]] karena keduanya terdiri dari [[monomer|satuan]]-satuan molekul yang disebut [[nukleotida]]. Tiap-tiap nukleotida terdiri atas salah satu jenis [[basa nitrogen]] ([[guanina]] (G), [[adenina]] (A), [[timina]] (T), atau [[sitosina]] (C)), gula [[monosakarida]] yang disebut [[deoksiribosa]], dan gugus [[fosfat]]. Nukleotida-nukelotida ini kemudian tersambung dalam satu rantai [[ikatan kovalen]] antara gula satu nukleotida dengan fosfat nukelotida lainnya. Hasilnya adalah rantai punggung gula-fosfat yang berselang-seling. Menurut kaidah [[pasangan basa]] (A dengan T dan C dengan G), [[ikatan hidrogen]] mengikat basa-basa dari kedua unting polinukleotida membentuk DNA unting ganda
#
# Dua unting DNA bersifat anti-paralel, yang berarti bahwa keduanya berpasangan secara berlawanan. Pada setiap gugus gula, terikat salah satu dari empat jenis nukleobasa. Urutan asam nukleat empat nukleobasa di sepanjang rantai punggung DNA inilah yang menyimpan kode informasi [[biologis]]. Melalui proses biokimia yang disebut [[transkripsi]], unting DNA digunakan sebagai templat untuk membuat unting [[RNA]]. Unting RNA ini kemudian ditranslasikan untuk menentukan urutan [[asam amino]] protein yang dibangun.
#
# Struktur kimia DNA yang ada membuatnya sangat cocok untuk menyimpan [[informasi]] biologis setiap makhluk hidup. Rantai punggung DNA resisten terhadap pembelahan kimia, dan kedua-dua unting dalam struktur unting ganda DNA menyimpan informasi biologis yang sama. Karenanya, informasi biologis ini akan direplikasi ketika dua unting DNA dipisahkan. Sebagian besar DNA (lebih dari 98% pada manusia) bersifat non-kode, yang berarti bagian ini tidak berfungsi menyandikan protein.
#
# Dalam sel, DNA tersusun dalam [[kromosom]]. Semasa [[pembelahan sel]], kromosom-kromosom ini diduplikasi dalam proses yang disebut [[replikasi DNA]]. [[Eukariota|Organisme eukariotik]] ([[hewan]], [[tumbuhan]], [[fungi]], dan [[protista]]) menyimpan kebanyakan DNA-nya dalam [[inti sel]] dan sebagian kecil sisanya dalam [[organel]] seperti [[mitokondria]] ataupun [[kloroplas]].<ref></ref> Sebaliknya [[prokariota|organisme prokariotik]] ([[bakteri]] dan [[arkaea]]) menyimpan DNA-nya hanya dalam [[sitoplasma]]. Dalam kromosom, protein [[kromatin]] seperti [[histon]] berperan dalam penyusunan DNA menjadi struktur kompak. Struktur kompak inilah yang kemudian berinteraksi antara DNA dengan protein lainnya, sehingga membantu kontrol bagian-bagian DNA mana sajakah yang dapat ditranskripsikan.
#
# Para ilmuwan menggunakan DNA sebagai alat molekuler untuk menyingkap teori-teori dan hukum-hukum fisika, seperti misalnya [[teorema ergodik]] dan teori [[elastisitas]]. Sifat-sifat materi DNA yang khas membuatnya sangat menarik untuk diteliti bagi ilmuwan dan insinyur yang bekerja di bidang mikrofabrikasi dan nanofabrikasi material. Beberapa kemajuan di bidang material ini misalnya [[origami DNA]] dan material hibrida berbasis DNA.<ref></ref>
#
# == Sifat-sifat DNA ==
# [[Berkas:DNA chemical structure_id.svg|jmpl|300px|Struktur kimia DNA; [[ikatan hidrogen]] ditunjukkan oleh garis putus-putus]]
# DNA merupakan sebuah [[polimer]] yang terdiri dari satuan-satuan berulang yang disebut [[nukleotida]].<ref></ref><ref name=Alberts></ref><ref name=Butler> pp. 14–15.</ref> Tiap-tiap nukleotida terdiri dari tiga komponen utama, yakni [[gugus fungsional|gugus]] [[fosfat]], gula deoksiribosa, dan basa nitrogen ([[nukleobasa]]).<ref></ref> Pada DNA, nukleobasa yang ditemukan adalah [[Adenina]] (A), [[Guanina]] (G), [[Sitosina]] (C) dan [[Timina]] (T). Nukleobasa yang terhubung dengan sebuah gugus gula disebut sebagai [[nukleosida]], dan nukleosida yang terhubung dengan satu atau lebih gugus fosfat disebut sebagai [[nukleotida]]. Polimer yang terdiri dari nukleotida yang saling terhubung menjadi satu rantai disebut sebagai [[polinukleotida]].<ref name="IUPAC">[http://www.chem.qmul.ac.uk/iupac/misc/naabb.html Abbreviations and Symbols for Nucleic Acids, Polynucleotides and their Constituents] IUPAC-IUB Commission on Biochemical Nomenclature (CBN). Retrieved 3 January 2006.</ref> Sehingga DNA termasuk pula ke dalam polinukleotida.
#
# Rantai punggung unting DNA terdiri dari gugus [[fosfat]] dan [[gula]] yang berselang-seling.<ref name=Ghosh></ref> Gula pada DNA adalah gula [[pentosa]] (berkarbon lima), yaitu 2-deoksiribosa. Dua gugus gula terhubung dengan fosfat melalui [[ikatan fosfodiester]] antara atom karbon ketiga pada cincin satu gula dan atom karbon kelima pada gula lainnya. Ikatan yang tidak simetris ini membuat DNA memiliki arah atau orientasi tertentu. Pada struktur heliks ganda, orientasi rantai nukleotida pada satu unting berlawanan dengan orientasi nukleotida unting lainnya. Hal ini disebut sebagai ''antiparalel''. Kedua ujung asimetris DNA disebut sebagai 5' (lima prima) dan 3' (tiga prima). Ujung 5' memiliki gugus fosfat terminus, sedangkan ujung 3' memiliki gugus hidroksi terminus. Salah satu perbedaan utama DNA dan RNA adalah gula penyusunnya, yakni gula 2-deoksiribosa pada DNA digantikan gula [[ribosa]] pada RNA.<ref name=berg/>
#
# Dalam organisme hidup, DNA biasanya ditemukan dalam bentuk berpasangan dan terikat kuat.<ref name="berg">Berg J., Tymoczko J. and Stryer L. (2002) ''Biochemistry.'' W. H. Freeman and Company ISBN 0-7167-4955-6</ref><ref name=autogenerated2></ref> Dua unting DNA saling berpilin membentuk [[heliks ganda]]. Heliks ganda ini distabilisasi oleh dua [[ikatan hidrogen]] antar nukleotida dan interaksi tumpukan antar nukleobasa [[aromatisitas|aromatik]].<ref name="Yakovchuk2006"></ref> Dalam lingkungan sel yang berair, [[ikatan pi|ikatan π]] konjugasi antar basa nukleotida tersusun tegak lurus terhadap sumbu pilinan DNA. Hal ini meminimalisasi interaksi dengan [[cangkang solvasi]], dan sehingganya menurunkan [[energi bebas Gibbs]].
#
# Struktur DNA semua jenis spesies terdiri dari dua rantai heliks yang berpilin dengan jarak antar putaran heliks 34&nbsp;[[Ångström|Å]] (3,4&nbsp;[[nanometer]]) dan jari-jari 10&nbsp;Å (1.0&nbsp;nanometer).<ref name=FWPUB></ref> Menurut kajian lainnya, ketika diukur menggunakan larutan tertentu, rantai DNA memiliki lebar 22-26&nbsp;Å (2,2-2,6&nbsp;nanometer) sedangkan satu satuan nukleotida memiliki panjang 33&nbsp;Å (0,33&nbsp;nm).<ref></ref> Walaupun satuan nukleotida ini sangatlah kecil, polimer DNA dapat memiliki jutaan nukleotida yang terangkai seperti rantai. Misalnya, [[kromosom 1 (manusia)|kromosom 1]] yang merupakan kromosom terbesar pada manusia mengandung sekitar 220 juta [[pasangan basa]].<ref></ref>
#
# === Nukleobasa DNA ===
# Nukleobasa diklasifikasikan ke dalam dua jenis: [[purina]] (A dan G) yang berupa fusi [[senyawa heterolingkar]] beranggota lima dengan [[senyawa heterolingkar]] beranggota enam, dan [[pirimidina]] (C dan T) yang berupa cincin beranggota enam.<ref name=berg/> Pirimidina lainnya, [[urasil]] (U), biasanya menggantikan timina pada RNA. Perbedaan urasil dengan timina terletak pada ketiadaan gugus [[metil]] pada cincin urasil. Selain kelima nukleobasa tersebut, terdapat pula sejumlah besar [[analog asam nukleat]] buatan yang telah disintesis untuk mengkaji sifat-sifat asam nukleat dan digunakan dalam bioteknologi.<ref></ref>
#
# Urasil biasanya tidak ditemukan dalam DNA (ditemukan dalam sel hanya sebagai produk uraian sitosina). Namun pada sejumlah [[bakteriofag]]– bakteriofag PBS1 dan PBS2 ''Bacillus subtilis'' dan bakteriofag piR1-37 ''Yersinia''– timina telah digantikan oleh urasil.<ref name=Kiljunen2005></ref> [[Fag]] lainnya - fag S6 Staphylococcus - juga telah diidentifikasi mempunyai urasil pada genomnya.<ref name=Uchiyama2014>Uchiyama J, Takemura-Uchiyama I, Sakaguchi Y, Gamoh K, Kato SI, Daibata M, Ujihara T, Misawa N, Matsuzaki S (2014) Intragenus generalized transduction in ''Staphylococcus'' spp. by a novel giant phage. ISME J. 2014 Mar 6. </ref>
#
# [[Basa J]] (beta-d-glukopiranosiloksimetilurasil) yang merupakan bentuk modifikasi dari urasil juga dapat ditemukan pada sejumlah organisme: [[flagellata]] ''[[Diplonema (protozoa)|Diplonema]]'' dan ''[[Euglena]]'', dan seluruh organisme marga [[kinetoplastid]]<ref name=Simpson1998></ref> Biosintesis basa J terjadi dalam dua tahap: pada tahap pertama, basa timina spesifik pada DNA diubah menjadi hidroksimetildeoksiuridina (HOMedU); pada tahap kedua HOMedU diglikosilasi menjadi basa J.<ref name=Borst2008></ref> Protein-protein yang mengikat basa J ini juga telah berhasil diidentifikasi.<ref name=Cross1999></ref><ref name=DiPaolo2005></ref><ref name=Vainio2009></ref> Protein-protein ini tampaknya merupakan kerabat jauh dari onkogen Tet1 yang terlibat dalam patogenesis [[leukemia myeloid akut]].<ref name=Iyer2009></ref> Basa J tampaknya bekerja sebagai sinyal terminasi untuk [[RNA polimerase II]].<ref name=van_Luenen2012></ref><ref name=Hazelbaker2012></ref>
#
# [[Berkas:DNA-ligand-by-Abalone.png|kiri|jmpl|Alur mayor dan minor DNA. Alur minor merupakan tapak pengikatan untuk [[Pewarna Hoechst|Hoechst 33258]].]]
#
# === Alur DNA ===
# Pada struktur heliks ganda DNA, terdapat ruang antar unting DNA yang juga berbentuk alur heliks. Ruang kosong ini bersebelahan dengan pasangan basa dan merupakan [[tapak ikatan]] yang potensial. Dikarenakan kedua unting DNA tidak berposisi secara simetris satu sama lainnya, alur yang dihasilkan jugalah tidak berukuran sama. Satu alur yang disebut alur mayor, memiliki lebar 22&nbsp;Å, sedangkan alur lainnya yang disebut alur minor, memiliki lebar 12&nbsp;Å.<ref></ref> Lebarnya alur mayor berarti bahwa tepi-tepi basa nukleotida dapat lebih mudah diakses melalui alur mayor daripada melalui alur minor. Akibatnya, protein-protein seperti [[faktor transkripsi|faktor-faktor transkripsi]] yang mengikat pada urutan basa tertentu biasanya melakukan kontak dengan basa melalui alur mayor.<ref name="Pabo1984"></ref> Situasi ini dapat bervariasi pada konformasi DNA yang tak lazim dalam sel, walaupun alur mayor dan minor selalu dinamai demikian untuk menrefleksikan perbedaan ukuran yang terlihat apabila DNA dipuntir balik menjadi bentuk lazim B.
#
# === Pemasangan basa ===
#
# Pada heliks ganda DNA, tiap jenis nukleobasa pada satu unting DNA berikatan hanya dengan satu jenis nukleobasa dari unting DNA lainnya. Hal ini disebut sebagai [[pasangan basa|pemasangan basa]] komplementer. Purina akan membentuk [[ikatan hidrogen]] dengan pirimidina; adenina berikatan dengan timina dalam dua ikatan hidrogen, dan sitosina berikatan dengan guanina dalam tiga ikatan hidrogen. Susunan dua nukleotida ini disebut sebagai satu pasangan basa. Karena ikatan hidrogen tidak bersifat [[ikatan kovalen|kovalen]], ia dapat putuskan dan digabung kembali relatif mudah. Kedua unting DNA dalam heliks ganda oleh karenanya dapat ditarik terbuka seperti zipper, baik melalui gaya mekanika maupun [[temperatur]] tinggi.<ref></ref> Karena pasangan basa ini bersifat komplementer, semua informasi pada urutan unting ganda heliks DNA terduplikasi pada tiap unting. Hal ini sangat penting dalam replikasi DNA. Interaksi reversible dan spesifik antara pasangan basa komplementer sangat kritikal terhadap keseluruhan fungsi DNA dalam makhluk hidup.<ref name=Alberts/>
# <div class="thumb tright" style="background:#f9f9f9; border:1px solid #ccc; margin:0.5em;">
# {| border="0" border="0" cellpadding="2" cellspacing="0" style="width:230px; font-size:85%; border:1px solid #ccc; margin:0.3em;"
# |-
# |[[Berkas:Base pair GC.svg|282px]]
# |}
# {| border="0" border="0" cellpadding="2" cellspacing="0" style="width:230px; font-size:85%; border:1px solid #ccc; margin:0.3em;"
# |-
# |[[Berkas:Base pair AT.svg|282px]]
# |}
# <div style="border: none; width:282px;"><div class="thumbcaption">Atas, pasangan basa '''GC''' dengan tiga [[ikatan hidrogen]]. Bawah, pasangan basa '''AT''' dengan dua ikatan hidrogen. Ikatan hidrogen non-kovalen ditunjukkan oleh garis putus-putus.</div></div></div> Dua jenis pasangan basa mempunyai jumlah ikatan hidrogen yang berbeda. Pasangan AT memiliki dua ikatan hidrogen, sedangkan pasangan GC memiliki tiga ikatan hidrogen. DNA yang mengandung pasangan basa GC yang tinggi lebih stabil daripada DNA berpasangan basa GC rendah.
#
# Sebagaimana telah disebutkan di atas, kebanyakan molekul DNA ditemukan dalam keadaan unting ganda yang berikatan secara non-kovalen dan berbentuk heliks. Struktur unting ganda ini ('''dsDNA''', ''double-stranded DNA'') utamanya distabilkan oleh interaksi tumpukan basa intra-unting. Interaksi yang terkuat ada pada tumpukan G dengan C. Kedua unting tersebut dapat dipisahkan menjadi dua molekul DNA unting tunggal ('''ssDNA''', ''single-stranded DNA'') melalui proses yang dinamakan ''peleburan'' DNA. Peleburan terjadi pada temperatur tinggi, kadar garam yang reandah, dan nilai pH yang tinggi (DNA juga melebur pada nilai pH rendah, tetapi dikarenakan DNA tidak stabil akibat depurinasi asam, peleburan pH rendah jarang digunakan).
#
# Stabilitas dsDNA tidak hanya bergantung pada kandungan GC (% pasangan basa G,C) DNA, namun juga tergantung pada urutan basa (tumpukan basa) dan panjang molekul DNA tersebut (molekul yang lebih panjang lebih stabil). Oleh sebab itu, kekuatan ikatan antar dua unting DNA ditentukan oleh persentase pasangan basa GC dan keseluruhan panjang heliks ganda DNA. Heliks DNA　yang panjang dengan kandungan GC yang tinggi memiliki interaksi antar-unting yang lebih kuat; sebaliknya heliks DNA yang pendek dengan kandungan AT yang tinggi memiliki interaksi antar-unting yang lebih lemah.<ref></ref> Dalam proses biologis, bagian heliks ganda DNA yang perlu dipisahkan dengan mudah seperti [[kotak Pribnow]] TATAAT pada beberapa [[promotor]] cenderung memiliki kandungan AT yang tinggi.<ref></ref>
#
# Stabilitas DNA dapat diukur melalui berbagai cara; umumnya stabilitas DNA diukur berdasarkan temperatur lebur DNA (disebut juga nilai ''T<sub>m</sub>''), yakni temperatur di mana 50% molekul DNA unting ganda terurai menjadi molekul DNA unting tunggal. Temperatur lebur ini bergantung pada kekuatan ionik dan konsentrasi DNA. Ketika seluruh pasangan basa dalam heliks ganda DNA terurai, kedua unting DNA akan terpisah sebagai dua molekul yang berdiri sendiri. Unting-unting tunggal DNA ini tidak memiliki bentuk tunggal yang sama, walaupun beberapa konformasi lebih stabil daripada konformasi lainnya.<ref></ref>
#
# === Sense dan antisense ===
#
#
# Sebuah urutan sekuens DNA disebut sebagai "sense" apabila urutan basa DNA-nya sama dengan urutan kopi [[RNA duta]] yang ditranslasikan menjadi protein.<ref>[http://www.chem.qmul.ac.uk/iubmb/newsletter/misc/DNA.html Designation of the two strands of DNA] JCBN/NC-IUB Newsletter 1989. Retrieved 7 May 2008</ref> Urutan pada unting komplementernya disebut sebagai urutan "antisense". Baik urutan sense dan antisense dapat ditemukan pada berbagai bagian unting DNA yang sama (kedua unting DNA dapat mengandung baik urutan sense maupun antisense). Pada prokariota dan eukariota, urutan RNA antisense juga diproduksi, namun fungsi RNA antisense ini tidaklah diketahui dengan jelas.<ref></ref> RNA antisense diajukan terlibat dalam regulasi [[ekspresi gen]] melalui pemasangan basa RNA-RNA.<ref></ref>
#
# Pada sebagian kecil urutan DNA prokariota dan eukariota, dan sebagian besar urutan DNA [[plasmid]] dan [[virus]], perbedaan antara unting sense dan antisense menjadi kabur dikarenakan terdapatnya [[gen tumpang tindih|gen yang tumpang tindih]].<ref></ref> Dalam hal ini, beberapa urutan DNA memiliki tugas ganda, yakni menyandikan protein pertama ketika dibaca melalui salah satu unting, dan menyandikan protein kedua ketika dibaca dengan arah berlawanan melalui unting komplementernya. Pada [[bakteri]], ketumpangtindihan ini kemungkinan terlibat dalam regulasi transkripsi gen.<ref></ref> Sedangkan pada virus, gen yang tumpang tindih ini meningkatkan jumlah informasi yang dapat disandikan dalam genom virus yang berukuran kecil.<ref></ref>
#
# === Pemilinan kumparan (''Supercoiling'') ===
#
# DNA dapat dipuntir menjadi seperti tali melalui proses yang disebut [[Kumparan terpilin DNA|pemilinan kumparan DNA]]. Pada kondisi "relaksasi", unting DNA biasanya akan mengitari sumbu heliks ganda setiap 10,4 pasangan basa. Namun jika DNA dipuntir, unting-untingnya dapat tergulung menjadi lebih rapat ataupun tergulung menjadi lebih longgar.<ref></ref> Jika DNA dipuntir searah putaran heliks, basa-basa dalam unting DNA akan terikat lebih rapat. Hal ini dinamakan pemilinan kumparan positif. Sebaliknya jika DNA dipuntir berlawanan putaran heliks, basa-basa dalam unting DNA akan terlepas lebih mudah. Hal ini dinamakan pemilinan kumparan negatif. Secara alamiah, kebanyakan DNA memiliki bentuk pemilinan kumparan negatif yang disebabkan oleh [[enzim]] [[topoisomerase]].<ref name=Champoux></ref> Enzim ini juga diperlukan untuk melepaskan tegangan puntiran yang dialami DNA semasa proses [[transkripsi]] dan [[replikasi]].<ref name=Wang></ref>
# [[Berkas:A-DNA, B-DNA and Z-DNA.png|jmpl|ka|Dari kiri ke kanan, struktur DNA A, DNA B, dan DNA Z]]
#
# === Struktur alternatif DNA ===
# Terdapat banyak kemungkinan [[Isomerisme konformasional|konformasi]]-konformasi DNA yang dapat kita temukan, di antaranya [[A-DNA]], B-DNA, dan [[Z-DNA]], walaupun hanya B-DNA dan Z-DNA saja yang telah diamati secara langsung pada organisme fungsional.<ref name=Ghosh/> Konformasi-konformasi yang diadopsi oleh DNA bergantung pada tingkat hidrasi DNA, urutan DNA, tingkat dan arah pilinan kumparan DNA, modifikasi kimiawi pada basa DNA, jenis dan konsentrasi ion-ion logam, maupun keberadaan [[poliamina]] dalam larutan.<ref></ref>
#
# === Basis buatan ===
# Beberapa nukleobasa buatan telah berhasil disintesis, dan berhasil dimasukkan ke dalam analog DNA berbasa delapan bernama [[DNA Hachimoji]].
#
# == Fungsi biologis ==
# === Replikasi ===
# [[Berkas:Dna-split.png|jmpl|Pada replikasi DNA, rantai DNA baru dibentuk berdasarkan urutan nukleotida pada DNA yang digandakan.]]
# [[Replikasi DNA|Replikasi]] merupakan proses pelipatgandaan DNA. Proses replikasi ini diperlukan ketika sel akan [[Pembelahan sel|membelah diri]]. Pada setiap sel, kecuali [[sel gamet]], pembelahan diri harus disertai dengan replikasi DNA supaya semua [[sel]] turunan memiliki informasi [[genetik]] yang sama. Pada dasarnya, proses replikasi memanfaatkan fakta bahwa DNA terdiri dari dua [[rantai DNA|rantai]] dan rantai yang satu merupakan "konjugat" dari rantai pasangannya. Dengan kata lain, dengan mengetahui susunan satu rantai, maka susunan rantai pasangan dapat dengan mudah dibentuk.
#
# Ada beberapa teori yang mencoba menjelaskan bagaimana proses replikasi DNA ini terjadi. Salah satu teori yang paling populer menyatakan bahwa pada masing-masing DNA baru yang diperoleh pada akhir proses replikasi; satu rantai tunggal merupakan rantai DNA dari rantai DNA sebelumnya, sedangkan rantai pasangannya merupakan rantai yang baru disintesis. Rantai tunggal yang diperoleh dari DNA sebelumnya tersebut bertindak sebagai "cetakan" untuk membuat rantai pasangannya.
#
# Proses replikasi memerlukan protein atau [[enzim]] pembantu; salah satu yang terpenting dikenal dengan nama [[DNA polimerase]], yang merupakan enzim pembantu pembentukan rantai DNA baru yang merupakan suatu [[polimer]]. Proses replikasi diawali dengan pembukaan untaian ganda DNA pada titik-titik tertentu di sepanjang rantai DNA. Proses pembukaan rantai DNA ini dibantu oleh enzim helikase yang dapat mengenali titik-titik tersebut, dan enzim girase yang mampu membuka pilinan rantai DNA.
#
# Setelah cukup ruang terbentuk akibat pembukaan untaian ganda ini, DNA polimerase masuk dan mengikat diri pada kedua rantai DNA yang sudah terbuka secara lokal tersebut. Proses pembukaan rantai ganda tersebut berlangsung disertai dengan pergeseran DNA polimerase mengikuti arah membukanya rantai ganda. Monomer DNA ditambahkan di kedua sisi rantai yang membuka setiap kali DNA polimerase bergeser. Hal ini berlanjut sampai seluruh rantai telah benar-benar terpisah.
#
# Proses replikasi DNA ini merupakan proses yang rumit namun teliti. Proses sintesis rantai DNA baru memiliki suatu mekanisme yang mencegah terjadinya kesalahan pemasukan monomer yang dapat berakibat fatal. Karena mekanisme inilah kemungkinan terjadinya kesalahan sintesis amatlah kecil.
# == Penggunaan DNA dalam teknologi ==
#
# === DNA dalam forensik ===
# [[Ilmu forensik|Ilmuwan forensik]] dapat menggunakan DNA yang terdapat dalam [[darah]], [[sperma]], [[kulit]], [[liur]] atau [[rambut]] yang tersisa di tempat kejadian kejahatan untuk mengidentifikasi kemungkinan tersangka, sebuah proses yang disebut [[fingerprinting genetika]] atau pemprofilan DNA (''DNA profiling''). Dalam pemprofilan DNA panjang relatif dari bagian DNA yang berulang seperti [[short tandem repeats]] dan [[minisatelit]], dibandingkan. Pemprofilan DNA dikembangkan pada [[1984]] oleh genetikawan Inggris [[Alec Jeffreys]] dari [[Universitas Leicester]], dan pertama kali digunakan untuk mendakwa [[Colin Pitchfork]] pada [[1988]] dalam kasus [[pembunuhan Enderby]] di [[Leicestershire]], [[Inggris]].
#
# Banyak yurisdiksi membutuhkan terdakwa dari kejahatan tertentu untuk menyediakan sebuah contoh DNA untuk dimasukkan ke dalam basis data komputer. Hal ini telah membantu investigator menyelesaikan kasus lama di mana pelanggar tidak diketahui dan hanya contoh DNA yang diperoleh dari tempat kejadian (terutama dalam kasus [[pemerkosaan]] antar orang tak dikenal). Metode ini adalah salah satu teknik paling tepercaya untuk mengidentifikasi seorang pelaku kejahatan, tetapi tidak selalu sempurna, misalnya bila tidak ada DNA yang dapat diperoleh, atau bila tempat kejadian terkontaminasi oleh DNA dari banyak orang.
#
# === DNA dalam komputasi ===
# DNA memainkan peran penting dalam [[ilmu komputer]], baik sebagai masalah riset dan sebagai sebuah cara komputasi.
#
# Riset dalam [[algoritme pencarian string]], yang menemukan kejadian dari urutan huruf di dalam urutan huruf yang lebih besar, dimotivasi sebagian oleh riset DNA, di mana algoritme ini digunakan untuk mencari urutan tertentu dari nukleotida dalam sebuah urutan yang besar. Dalam aplikasi lainnya seperti [[editor text]], bahkan algoritme sederhana untuk masalah ini biasanya mencukupi, tetapi urutan DNA menyebabkan algoritme-algoritme ini untuk menunjukkan sifat kasus-mendekati-terburuk dikarenakan jumlah kecil dari karakter yang berbeda.
#
# Teori [[database]] juga telah dipengaruhi oleh riset DNA, yang memiliki masalah khusus untuk menaruh dan memanipulasi urutan DNA. Database yang dikhususkan untuk riset DNA disebut [[database genomik]], dam harus menangani sejumlah tantangan teknis yang unik yang dihubungkan dengan operasi pembandingan kira-kira, pembandingan urutan, mencari pola yang berulang, dan pencarian homologi.
#
# == Sejarah ==
# DNA pertama kali berhasil dimurnikan pada tahun 1868 oleh ilmuwan Swiss [[Friedrich Miescher]] di [[Tubingen]], [[Jerman]], yang menamainya ''nuclein'' berdasarkan lokasinya di dalam inti sel. Namun, penelitian terhadap peranan DNA di dalam sel baru dimulai pada awal abad 20, bersamaan dengan ditemukannya postulat genetika [[Gregor Mendel|Mendel]]. DNA dan [[protein]] dianggap dua molekul yang paling memungkinkan sebagai pembawa sifat genetis berdasarkan teori tersebut.
#
# Dua eksperimen pada dekade 40-an membuktikan fungsi DNA sebagai materi genetik. Dalam penelitian oleh [[Oswald Avery|Avery]] dan rekan-rekannya, ekstrak dari sel bakteri yang satu gagal men-[[transformasi|transform]] sel bakteri lainnya kecuali jika DNA dalam ekstrak dibiarkan utuh. [[Percobaan Hershey-Chase|Eksperimen]] yang dilakukan [[Alfred Hershey|Hershey]] dan [[Martha Chase|Chase]] membuktikan hal yang sama dengan menggunakan [[pencari jejak radioaktif]] ().
#
# Misteri yang belum terpecahkan ketika itu adalah: "''bagaimanakah struktur DNA sehingga ia mampu bertugas sebagai materi genetik''". Persoalan ini dijawab oleh [[Francis Crick]] dan koleganya [[James Watson]] berdasarkan hasil [[difraksi]] [[sinar X]] pada DNA oleh [[Maurice Wilkins]] dan [[Rosalind Franklin]].
#
# Pada tahun 1953, James Watson dan Francis Crick mendefinisikan DNA sebagai [[polimer]] yang terdiri dari 4 [[basa]] dari [[asam nukleat]], dua dari kelompok [[purina]]:adenina dan guanina; dan dua lainnya dari kelompok [[pirimidina]]:sitosina dan timina. Keempat [[nukleobasa]] tersebut terhubung dengan [[glukosa fosfat]].<ref></ref>
#
# Maurice Wilkins dan Rosalind Franklin menemukan bahwa molekul DNA berbentuk [[heliks]] yang berputar setiap 3,4&nbsp;nm, sedangkan jarak antar molekul nukleobasa adalah 0,34&nbsp;nm, hingga dapat ditentukan bahwa terdapat 10 molekul nukleobasa pada setiap putaran DNA. Setelah diketahui bahwa [[diameter]] heliks DNA sekitar 2&nbsp;nm, baru diketahui bahwa DNA terdiri bukan dari 1 rantai, melainkan 2 rantai heliks.
#
# Crick, Watson, dan Wilkins mendapatkan hadiah [[Nobel Kedokteran]] pada 1962 atas penemuan ini. Franklin, karena sudah wafat pada waktu itu, tidak dapat dianugerahi hadiah ini.
#
# Konfirmasi akhir mekanisme [[replikasi DNA]] dilakukan lewat [[percobaan Meselson-Stahl]] yang dilakukan tahun 1958.
#
# == Referensi ==
#
#
#
#
#
# [[Kategori:Genetika molekular|Nukleat asam DNA]]
# [[Kategori:Asam nukleat]]

# %% [markdown]
# ## 4.Data Cleaning and Extraction
#
# Membersihkan text dari markup Wikipedia dan mengekstrak informasi.
# **Fungsi Utama:**
# - Ekstrak kategori dari format `[[Kategori:...]]`
# - Pembersihan teks lengkap (hapus ref, link, template, dsb)

# %%
# mengambil 1 sampel text sebagai contoh
sample_text = df.loc[0, 'text']

# %% [markdown]
# ### 4.1 Esktrak informasi kategori
#
# `[[Kategori:Genetika molekular|Nukleat asam DNA]]`
#
# `[[Kategori:Asam nukleat]]`

# %%
# mencari dan mengekstrak informasi kategori artikel dari teks
x = re.findall(r'\[\[Kategori:(.*?)\]\]', sample_text)
kategori_extracted = []
for kategori in x:
    kategori_extracted.extend(kategori.split('|'))
print(kategori_extracted)
# Out:
# ['Genetika molekular', 'Nukleat asam DNA', 'Asam nukleat']

# %%
# Modularisasi ke bentuk fungsi, agar lebih mudah digunakan pada dataframe
def extract_kategori(text):
    x = re.findall(r'\[\[Kategori:(.*?)\]\]',text)
    kategori_extracted = []
    for kategori in x:
        kategori_extracted.extend(kategori.split('|'))
    return kategori_extracted

# %%
# menjalankan fungsi terhadap sample_text
extract_kategori(sample_text)
# Out:
# ['Genetika molekular', 'Nukleat asam DNA', 'Asam nukleat']

# %% [markdown]
# ### 4.2 Membersihkan/ Menghapus markdown files
# `[[Berkas:DNA animation.gif|jmpl|Gambaran tiga dimensi DNA]]{{genetika}}`

# %%
#mencari dan menghapus semua markdown files
sample_text_clean = re.sub(r'\[\[Berkas:.*?\n','', sample_text, flags=re.IGNORECASE)
# print(re.sub(r'\[\[Berkas:.*?\n','', sample_text, flags=re.IGNORECASE))

# %% [markdown]
# ### 4.3 Membersihkan/Menghapus reftag
# `<ref>{{cite book|last = Saenger|first = Wolfram|title = Principles of Nucleic Acid Structure|url = https://archive.org/details/...
# }}</ref>`

# %%
#mencari dan menghapus semua reftag
sample_text_clean = re.sub(r'<ref.*?<\/ref>', '', sample_text_clean, flags=re.DOTALL)
# print(sample_text_clean)

# %% [markdown]
# ### 4.4 Membersihkan internal link
#
# `[[Hereditas|pewarisan]]` akan  menjadi `pewarisan` (hanya mengambil labelnya saja)
#
# `[[kromosom]]` akan menjadu `kromosom`

# %%
#cleansing internal link dengan label
sample_text_clean = re.sub(r'\[\[[\w\s]*?\|([\w\s]*?)\]\]',r'\1', sample_text_clean)
# print(sample_text_clean)

# %%
#cleansing internal link tanpa label
sample_text_clean = re.sub(r'\[\[([\w\s]*)\]\]', r'\1', sample_text_clean)
# print(sample_text_clean)

# %%
def cleanse_text(text):
    text = re.sub(r'\[\[(Berkas|File).*?\n',' ',text, flags=re.IGNORECASE)
    text = re.sub(r'<ref.*?<\/ref>', ' ', text, flags=re.DOTALL)
    text = re.sub(r'\[\[[\w\s]*?\|([\w\s]*?)\]\]',r'\1',text)
    text = re.sub(r'\[\[(.*?)\]\]', r'\1', text)
    text = text.strip()
    return text

# %%
# mencoba fungsi pada sample_text dan membandingkan hasil sebelum dan sesudah cleansing

clean_text = cleanse_text(sample_text)

print("=== SEBELUM (Raw) ===")
print(sample_text[:300]) # Print 300 karakter pertama aja
print("\n" + "="*20 + "\n")
print("=== SESUDAH (Clean) ===")
print(clean_text[:300])
# Out:
# === SEBELUM (Raw) ===
# [[Berkas:DNA Structure+Key+Labelled.pn NoBB.png|jmpl|ka|340px|Struktur [[heliks ganda]] DNA. [[Atom]]-atom pada struktur tersebut diwarnai sesuai dengan [[unsur kimia]]nya dan struktur detail dua pasangan basa ditunjukkan oleh gambar kanan bawah]]
# [[Berkas:DNA animation.gif|jmpl|Gambaran tiga dimens
#
# ====================
#
# === SESUDAH (Clean) ===
# '''Asam deoksiribonukleat''', lebih dikenal dengan singkatan '''DNA''' (bahasa Inggris: '''''d'''eoxyribo'''n'''ucleic '''a'''cid''), adalah salah satu jenis asam nukleat yang memiliki kemampuan pewarisan sifat. Keberadaan asam deoksiribonukleat ditemukan di dalam nukleoprotein yang membentuk inti s

# %% [markdown]
# ## 5. Eksekusi Data Cleaning Pipeline
#
# Menerapkan semua fungsi pembersihan secara berurutan menggunakan method chaining `.pipe()`.
#
# Output: `df_cleaned` - Dataset yang sudah bersih dengan kolom text_cleaned dan kategori
#
# **Fungsi Pipeline:**
# - `start_pipeline()`: Mulai pipeline
# - `extract_kategori_pipe()`:  ekstraksi kategori
# - `clean_text_pipe()`:  pembersihan text
# - `clean_nested_template_pipe()`: menghapus template bersarang

# %%
# data pipeline
def start_pipeline(df):
    return df.copy()

def extract_kategori_pipe(df):
    df['kategori'] = df['text'].apply(extract_kategori)
    return df

def cleanse_text_pipe(df):
    df['text_cleaned'] = df['text'].apply(cleanse_text)
    return df

# %%
#menjalankan proses pembersihan pada dataframe
df_cleaned = (df
              .pipe(start_pipeline)
              .pipe(extract_kategori_pipe)
              .pipe(cleanse_text_pipe)
              )
print(df_cleaned.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86436 entries, 0 to 86435
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    86436 non-null  int64
#  1   id            86436 non-null  int64
#  2   timestamp     86436 non-null  object
#  3   title         86436 non-null  object
#  4   text          86436 non-null  object
#  5   kategori      86436 non-null  object
#  6   text_cleaned  86436 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 4.6+ MB
# None

# %%
# menampilkan hasil cleansing dan ekstraksi pada dataframe

# %% [markdown]
# ## 6. Feature Extraction
#
# - **Tokenisasi** : Merubah teks utuh menjadi komponen-komponen token
# - **Vektorisasi**: Mengkonversi text menjadi numerical feature menggunakan TF-IDF (Term Frequency-Inverse Document
#
# **Output**: TF-IDF matrix - menghasilkan matrix yang merupakan representasi numerik dari setiap teks/dookumen

# %% [markdown]
# ### 6.1 Tokenisasi
#
# #### Mengapa Tokenisasi Penting?
#
# 1. **Pemrosesan Komputer**: Algoritma machine learning memerlukan input yang terstruktur. Tokenisasi mengubah teks yang tidak terstruktur menjadi deretan token yang dapat dianalisis secara sistematis.
#
# 2. **Pengurangan Kompleksitas**: Memecah teks besar menjadi satuan kecil memudahkan pemrosesan dan analisis yang lebih efisien.
#
# 3. **Ekstraksi Fitur**: Token individual menjadi basis untuk ekstraksi fitur lanjutan seperti TF-IDF, word embeddings, dan analisis frekuensi.
#
# #### Contoh Tokenisasi Sederhana (Word-Level Tokenization)
#
# Teks asli:
# ```
# "Indonesia adalah negara kepulauan terbesar di dunia yang terletak di Asia Tenggara"
# ```
#
# Setelah tokenisasi dengan memisahkan berdasarkan spasi:
# ```
# ['Indonesia', 'adalah', 'negara', 'kepulauan', 'terbesar', 'di', 'dunia', 'yang', 'terletak', 'di', 'Asia', 'Tenggara']
# ```
#
# Jumlah token: **12 token**

# %%
# simple tokenization
sample_text = 'Indonesia adalah negara kepulauan terbesar di dunia yang terletak di Asia Tenggara'

# %%
#mencoba tokenisasi sederhana (word level)
sample_text.split(' ')
# Out:
# ['Indonesia',
#  'adalah',
#  'negara',
#  'kepulauan',
#  'terbesar',
#  'di',
#  'dunia',
#  'yang',
#  'terletak',
#  'di',
#  'Asia',
#  'Tenggara']

# %% [markdown]
# ### 6.2 Vektorisasi Teks (Text Vectorization)
#
# **Vektorisasi** adalah proses fundamental dalam *Natural Language Processing* (NLP) untuk mengubah data teks tidak terstruktur menjadi representasi numerik (vektor) yang dapat dipahami oleh mesin.
#
# Bayangkan vektorisasi sebagai **penerjemah**: Komputer tidak mengerti kata "Apel" atau "Jeruk", tetapi mereka mengerti bahwa `[1, 0]` berbeda dengan `[0, 1]`.
#
# #### Mengapa Vektorisasi Penting?
#
# Komputer bekerja dengan operasi aljabar linier. Tanpa vektorisasi, algoritma machine learning tidak dapat memproses input teks.
# 1.  **Kompatibilitas Matematis**: Algoritma seperti Regresi, SVM, atau Neural Networks membutuhkan input berupa array angka (matriks).
# 2.  **Menangkap Makna (Semantik)**: Teknik vektorisasi yang baik tidak hanya mengubah kata jadi angka, tapi juga mempertahankan informasi penting seperti seberapa unik kata tersebut dalam sebuah dokumen.
# 3.  **Pengukuran Jarak**: Memungkinkan kita menghitung *similarity* (kemiripan) antar dokumen menggunakan rumus geometri seperti *Cosine Similarity* atau *Euclidean Distance*.
#
# ---
#
# #### Beberapa Metode Vektorisasi
#
# Berikut adalah beberapa pendekatan populer, diurutkan dari yang paling sederhana hingga metode yang kami pilih:
#
# ##### 1. One-Hot Encoding
# Setiap kata dalam *vocabulary* diwakili oleh satu bit unik.
# * **Konsep**: Jika kita memiliki 1.000 kata unik, setiap kata adalah vektor sepanjang 1.000 dimensi dengan satu angka `1` dan sisanya `0`.
# * **Kelemahan**: Menghasilkan dimensi yang sangat besar (*high dimensionality*) dan tidak menangkap frekuensi kata.
#
# ##### 2. Bag of Words (BoW) / Count Vectorizer
# Metode ini menghitung **frekuensi** kemunculan kata dalam dokumen tanpa memperdulikan urutan.
# * **Analogi**: Bayangkan sebuah dokumen dipotong-potong per kata, lalu dimasukkan ke dalam kantong (bag). Kita hanya menghitung jumlah kata "makan" ada berapa, "tidur" ada berapa.
# * **Kelemahan**: Kata umum seperti "yang", "dan", "di" akan memiliki nilai (bobot) yang sangat besar, padahal kata-kata tersebut minim informasi unik.
#
# ##### 3. TF-IDF (Term Frequency - Inverse Document Frequency)
# Metode ini adalah penyempurnaan dari BoW. TF-IDF memberikan bobot pada kata berdasarkan dua prinsip:
# 1.  **Seberapa sering** kata muncul di dokumen ini? (TF)
# 2.  **Seberapa jarang** kata muncul di seluruh koleksi dokumen lain? (IDF)
#
# Tujuannya adalah menonjolkan kata yang **sering muncul di satu dokumen tertentu, tapi jarang muncul di dokumen lain** .
#
# ---
#
# #### Algoritma TF-IDF
#
# Rumus matematis untuk menghitung bobot kata $t$ dalam dokumen $d$:
#
# $$W_{t,d} = \text{TF}(t,d) \times \text{IDF}(t)$$
#
# Dimana:
#
# 1.  **Term Frequency (TF)**: Frekuensi kata dalam dokumen tertentu.
#     $$\text{TF}(t,d) = \frac{\text{Jumlah kemunculan kata } t \text{ di dokumen } d}{\text{Total kata dalam dokumen } d}$$
#
# 2.  **Inverse Document Frequency (IDF)**: Mengukur seberapa informatif sebuah kata.
#     $$\text{IDF}(t) = \log \left( \frac{\text{Total Dokumen } (N)}{\text{Jumlah Dokumen yang mengandung kata } t} \right)$$
#
# **Simulasi Perhitungan Sederhana:**
#
# Misalkan kita memiliki data teks:
# * **Doc A**: "Kucing makan ikan"
# * **Doc B**: "Kucing tidur"
# * **Doc C**: "Ikan berenang"
#
# Nilai bobot untuk kata **"Kucing"** di **Doc A**:
#
# 1.  **TF ("Kucing", Doc A)**: Muncul 1 kali dari 3 total kata = $1/3 \approx 0.33$
# 2.  **IDF ("Kucing")**: Muncul di 2 dokumen (A & B) dari total 3 dokumen.
#     $$\text{IDF} = \log(3/2) \approx 0.176$$
# 3.  **TF-IDF**: $0.33 \times 0.176 = \mathbf{0.058}$
#
# Bandingkan dengan kata **"Berenang"** di **Doc C**:
# 1.  **TF**: $1/2 = 0.5$
# 2.  **IDF**: Muncul hanya di 1 dokumen. $\log(3/1) \approx 0.477$
# 3.  **TF-IDF**: $0.5 \times 0.477 = \mathbf{0.238}$
#
# > **Insight**: Kata "Berenang" memiliki bobot lebih tinggi daripada "Kucing" karena "Berenang" lebih spesifik/langka dalam koleksi dokumen ini.
#
# ---
#
# #### Output Vektorisasi: Sparse Matrix
#
# Hasil dari proses ini adalah sebuah matriks di mana:
# * **Baris**: Dokumen (Artikel Wikipedia)
# * **Kolom**: Kata (Fitur/Vocabulary)
# * **Nilai**: Skor TF-IDF
#
# Karena sebagian besar kata tidak muncul di setiap dokumen, matriks ini akan didominasi oleh angka nol. Untuk menghemat memori, ini disimpan sebagai **Sparse Matrix**.
#
# **Ilustrasi Matriks TF-IDF:**
#
# | Dokumen | 'indonesia' | 'adalah' | 'kepulauan' | 'teknologi' | 'ekonomi' |
# | :--- | :---: | :---: | :---: | :---: | :---: |
# | **Artikel 1** | 0.45 | 0.02 | 0.65 | 0.00 | 0.00 |
# | **Artikel 2** | 0.00 | 0.02 | 0.00 | 0.55 | 0.35 |
# | **Artikel 3** | 0.30 | 0.01 | 0.00 | 0.00 | 0.75 |
#
# *Catatan: Nilai 0.00 merepresentasikan kata tersebut tidak ada dalam dokumen.*

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

# %%
# membuat daftar stop_words
stop_words = ['yang', 'dan', 'ini', 'itu']

# %%
# vektorisasi menggunakan TfIdf
vectorizer = TfidfVectorizer(lowercase=True, dtype=np.float32, max_features=50000, stop_words=stop_words)
vectorizer.fit_transform(df_cleaned['text_cleaned'])
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float32'
# 	with 31904468 stored elements and shape (86436, 50000)>

# %%
#mlihat daftar vocabulary
vectorizer.vocabulary_
# Out:
# {'asam': np.int64(4998),
#  'lebih': np.int64(25816),
#  'dikenal': np.int64(12795),
#  'dengan': np.int64(11912),
#  'singkatan': np.int64(42357),
#  'dna': np.int64(13879),
#  'bahasa': np.int64(5737),
#  'inggris': np.int64(20626),
#  'cid': np.int64(10029),
#  'adalah': np.int64(2921),
#  'salah': np.int64(40145),
#  'satu': np.int64(40544),
#  'jenis': np.int64(21662),
#  'nukleat': np.int64(32688),
#  'memiliki': np.int64(28692),
#  'kemampuan': np.int64(23376),
#  'pewarisan': np.int64(36250),
#  'sifat': np.int64(42126),
#  'keberadaan': np.int64(22977),
#  'ditemukan': np.int64(13663),
#  'di': np.int64(12197),
#  'dalam': np.int64(11358),
#  'membentuk': np.int64(28563),
#  'inti': np.int64(20862),
#  'sel': np.int64(41105),
#  'james': np.int64(21415),
#  'dewey': np.int64(12156),
#  'watson': np.int64(48540),
#  'francis': np.int64(16691),
#  'crick': np.int64(10980),
#  'merupakan': np.int64(30208),
#  'ilmuwan': np.int64(20310),
#  'pertama': np.int64(36057),
#  'mengajukan': np.int64(29198),
#  'model': np.int64(30812),
#  'struktur': np.int64(43562),
#  'pada': np.int64(33557),
#  'tahun': np.int64(44483),
#  '1953': np.int64(1268),
#  'bentuk': np.int64(6635),
#  'ganda': np.int64(17119),
#  'setiap': np.int64(41629),
#  'tersusun': np.int64(45682),
#  'dari': np.int64(11488),
#  'dua': np.int64(14218),
#  'buah': np.int64(8583),
#  'rantai': np.int64(38352),
#  'sejenis': np.int64(41024),
#  'menyimpan': np.int64(29990),
#  'instruksi': np.int64(20753),
#  'genetika': np.int64(17397),
#  'organisme': np.int64(33278),
#  'banyak': np.int64(6004),
#  'virus': np.int64(48112),
#  'berperan': np.int64(7261),
#  'penting': np.int64(35417),
#  'pertumbuhan': np.int64(36101),
#  'perkembangan': np.int64(35843),
#  'fungsi': np.int64(16889),
#  'bersamaan': np.int64(7308),
#  'protein': np.int64(37533),
#  'karbohidrat': np.int64(22609),
#  'esensial': np.int64(15294),
#  'bagi': np.int64(5710),
#  'seluruh': np.int64(41203),
#  'makhluk': np.int64(27234),
#  'hidup': np.int64(19359),
#  'diketahui': np.int64(12808),
#  'kebanyakan': np.int64(22966),
#  'molekul': np.int64(30891),
#  'terdiri': np.int64(45371),
#  'sama': np.int64(40218),
#  'lainnya': np.int64(25422),
#  'heliks': np.int64(19121),
#  'sebagai': np.int64(40840),
#  'karena': np.int64(22627),
#  'keduanya': np.int64(23096),
#  'satuan': np.int64(40545),
#  'disebut': np.int64(13437),
#  'nukleotida': np.int64(32694),
#  'tiap': np.int64(45976),
#  'atas': np.int64(5195),
#  'basa': np.int64(6150),
#  'nitrogen': np.int64(32401),
#  'atau': np.int64(5201),
#  'gula': np.int64(18308),
#  'monosakarida': np.int64(30973),
#  'gugus': np.int64(18279),
#  'fosfat': np.int64(16614),
#  'kemudian': np.int64(23450),
#  'tersambung': np.int64(45639),
#  'ikatan': np.int64(20245),
#  'kovalen': np.int64(24868),
#  'antara': np.int64(4395),
#  'hasilnya': np.int64(18910),
#  'punggung': np.int64(37766),
#  'berselang': np.int64(7330),
#  'seling': np.int64(41176),
#  'menurut': np.int64(29852),
#  'kaidah': np.int64(22256),
#  'pasangan': np.int64(34103),
#  'hidrogen': np.int64(19347),
#  'mengikat': np.int64(29494),
#  'kedua': np.int64(23094),
#  'bersifat': np.int64(7357),
#  'anti': np.int64(4429),
#  'paralel': np.int64(33945),
#  'berarti': np.int64(6707),
#  'bahwa': np.int64(5751),
#  'berpasangan': np.int64(7240),
#  'secara': np.int64(40887),
#  'berlawanan': np.int64(7128),
#  'terikat': np.int64(45435),
#  'empat': np.int64(14987),
#  'urutan': np.int64(47561),
#  'sepanjang': np.int64(41409),
#  'inilah': np.int64(20644),
#  'kode': np.int64(24374),
#  'informasi': np.int64(20605),
#  'biologis': np.int64(7795),
#  'melalui': np.int64(28258),
#  'proses': np.int64(37515),
#  'biokimia': np.int64(7791),
#  'transkripsi': np.int64(46595),
#  'digunakan': np.int64(12637),
#  'templat': np.int64(45141),
#  'untuk': np.int64(47475),
#  'membuat': np.int64(28615),
#  'rna': np.int64(39406),
#  'menentukan': np.int64(29138),
#  'amino': np.int64(3993),
#  'dibangun': np.int64(12333),
#  'kimia': np.int64(24106),
#  'ada': np.int64(2915),
#  'membuatnya': np.int64(28618),
#  'sangat': np.int64(40341),
#  'cocok': np.int64(10334),
#  'resisten': np.int64(39019),
#  'terhadap': np.int64(45415),
#  'pembelahan': np.int64(34636),
#  'karenanya': np.int64(22628),
#  'akan': np.int64(3401),
#  'ketika': np.int64(23900),
#  'dipisahkan': np.int64(13219),
#  'sebagian': np.int64(40844),
#  'besar': np.int64(7512),
#  '98': np.int64(2579),
#  'manusia': np.int64(27535),
#  'non': np.int64(32503),
#  'bagian': np.int64(5711),
#  'tidak': np.int64(45991),
#  'berfungsi': np.int64(6867),
#  'kromosom': np.int64(24986),
#  'semasa': np.int64(41226),
#  'replikasi': np.int64(38926),
#  'eukariotik': np.int64(15426),
#  'hewan': np.int64(19293),
#  'tumbuhan': np.int64(46925),
#  'fungi': np.int64(16888),
#  'protista': np.int64(37544),
#  'nya': np.int64(32766),
#  'kecil': np.int64(23046),
#  'sisanya': np.int64(42449),
#  'organel': np.int64(33271),
#  'seperti': np.int64(41435),
#  'mitokondria': np.int64(30723),
#  'ataupun': np.int64(5203),
#  'kloroplas': np.int64(24298),
#  'sebaliknya': np.int64(40849),
#  'bakteri': np.int64(5811),
#  'hanya': np.int64(18748),
#  'sitoplasma': np.int64(42488),
#  'penyusunan': np.int64(35567),
#  'menjadi': np.int64(29702),
#  'kompak': np.int64(24520),
#  'berinteraksi': np.int64(6957),
#  'sehingga': np.int64(40985),
#  'membantu': np.int64(28521),
#  'kontrol': np.int64(24729),
#  'mana': np.int64(27362),
#  'dapat': np.int64(11465),
#  'para': np.int64(33926),
#  'menggunakan': np.int64(29414),
#  'alat': np.int64(3565),
#  'molekuler': np.int64(30893),
#  'menyingkap': np.int64(29997),
#  'teori': np.int64(45231),
#  'hukum': np.int64(19865),
#  'fisika': np.int64(16355),
#  'misalnya': np.int64(30666),
#  'teorema': np.int64(45228),
#  'elastisitas': np.int64(14780),
#  'materi': np.int64(27903),
#  'khas': np.int64(23996),
#  'menarik': np.int64(28933),
#  'diteliti': np.int64(13648),
#  'insinyur': np.int64(20715),
#  'bekerja': np.int64(6467),
#  'bidang': np.int64(7669),
#  'material': np.int64(27904),
#  'beberapa': np.int64(6379),
#  'kemajuan': np.int64(23369),
#  'origami': np.int64(33298),
#  'hibrida': np.int64(19317),
#  'berbasis': np.int64(6740),
#  'sebuah': np.int64(40876),
#  'polimer': np.int64(36820),
#  'berulang': np.int64(7483),
#  'tiga': np.int64(46014),
#  'komponen': np.int64(24547),
#  'utama': np.int64(47630),
#  'yakni': np.int64(49263),
#  'terhubung': np.int64(45428),
#  'nukleosida': np.int64(32692),
#  'saling': np.int64(40180),
#  'termasuk': np.int64(45542),
#  'pula': np.int64(37727),
#  'ke': np.int64(22912),
#  'lima': np.int64(26239),
#  'yaitu': np.int64(49259),
#  'atom': np.int64(5259),
#  'karbon': np.int64(22611),
#  'ketiga': np.int64(23896),
#  'cincin': np.int64(10067),
#  'kelima': np.int64(23320),
#  'simetris': np.int64(42251),
#  'arah': np.int64(4675),
#  'orientasi': np.int64(33294),
#  'tertentu': np.int64(45695),
#  'hal': np.int64(18575),
#  'ujung': np.int64(47220),
#  'asimetris': np.int64(5055),
#  'prima': np.int64(37310),
#  'terminus': np.int64(45547),
#  'sedangkan': np.int64(40912),
#  'perbedaan': np.int64(35659),
#  'penyusunnya': np.int64(35568),
#  'digantikan': np.int64(12608),
#  'oleh': np.int64(33038),
#  'antar': np.int64(4394),
#  'interaksi': np.int64(20803),
#  'tumpukan': np.int64(46940),
#  'aromatik': np.int64(4883),
#  'lingkungan': np.int64(26295),
#  'berair': np.int64(6665),
#  'konjugasi': np.int64(24626),
#  'tegak': np.int64(45003),
#  'lurus': np.int64(26848),
#  'sumbu': np.int64(43878),
#  'cangkang': np.int64(9158),
#  'menurunkan': np.int64(29850),
#  'energi': np.int64(15059),
#  'bebas': np.int64(6372),
#  'gibbs': np.int64(17618),
#  'semua': np.int64(41282),
#  'spesies': np.int64(43105),
#  'jarak': np.int64(21484),
#  'putaran': np.int64(37856),
#  '34': np.int64(1670),
#  'nbsp': np.int64(31964),
#  'nanometer': np.int64(31777),
#  'jari': np.int64(21493),
#  '10': np.int64(144),
#  'kajian': np.int64(22282),
#  'diukur': np.int64(13752),
#  'larutan': np.int64(25632),
#  'lebar': np.int64(25810),
#  '22': np.int64(1456),
#  '26': np.int64(1524),
#  'panjang': np.int64(33871),
#  '33': np.int64(1656),
#  'nm': np.int64(32426),
#  'walaupun': np.int64(48364),
#  'sangatlah': np.int64(40342),
#  'jutaan': np.int64(22118),
#  'terbesar': np.int64(45312),
#  'mengandung': np.int64(29233),
#  'sekitar': np.int64(41068),
#  '220': np.int64(1457),
#  'juta': np.int64(22117),
#  'diklasifikasikan': np.int64(12821),
#  'berupa': np.int64(7491),
#  'fusi': np.int64(16915),
#  'senyawa': np.int64(41385),
#  'enam': np.int64(15018),
#  'biasanya': np.int64(7635),
#  'produk': np.int64(37413),
#  'uraian': np.int64(47519),
#  'namun': np.int64(31754),
#  'sejumlah': np.int64(41029),
#  'bacillus': np.int64(5649),
#  '37': np.int64(1711),
#  'telah': np.int64(45052),
#  'fag': np.int64(15731),
#  's6': np.int64(39923),
#  'staphylococcus': np.int64(43306),
#  'juga': np.int64(22010),
#  'diidentifikasi': np.int64(12682),
#  'mempunyai': np.int64(28829),
#  'beta': np.int64(7531),
#  'modifikasi': np.int64(30832),
#  'protozoa': np.int64(37552),
#  'marga': np.int64(27606),
#  'biosintesis': np.int64(7805),
#  'terjadi': np.int64(45454),
#  'tahap': np.int64(44469),
#  'spesifik': np.int64(43107),
#  'diubah': np.int64(13748),
#  'berhasil': np.int64(6920),
#  'tampaknya': np.int64(44662),
#  'kerabat': np.int64(23630),
#  'jauh': np.int64(21537),
#  'terlibat': np.int64(45529),
#  'leukemia': np.int64(26065),
#  'akut': np.int64(3530),
#  'sinyal': np.int64(42408),
#  'polimerase': np.int64(36821),
#  'ii': np.int64(20221),
#  'alur': np.int64(3869),
#  'terdapat': np.int64(45358),
#  'ruang': np.int64(39742),
#  'berbentuk': np.int64(6753),
#  'kosong': np.int64(24838),
#  'bersebelahan': np.int64(7320),
#  'tapak': np.int64(44779),
#  'potensial': np.int64(37029),
#  'dikarenakan': np.int64(12767),
#  'berposisi': np.int64(7280),
#  'dihasilkan': np.int64(12662),
#  'jugalah': np.int64(22011),
#  'berukuran': np.int64(7482),
#  'mayor': np.int64(28038),
#  'minor': np.int64(30608),
#  '12': np.int64(380),
#  'lebarnya': np.int64(25812),
#  'tepi': np.int64(45239),
#  'mudah': np.int64(31263),
#  'diakses': np.int64(12232),
#  'daripada': np.int64(11493),
#  'akibatnya': np.int64(3438),
#  'faktor': np.int64(15771),
#  'melakukan': np.int64(28255),
#  'kontak': np.int64(24697),
#  'situasi': np.int64(42495),
#  'bervariasi': np.int64(7498),
#  'konformasi': np.int64(24605),
#  'tak': np.int64(44525),
#  'lazim': np.int64(25756),
#  'selalu': np.int64(41112),
#  'dinamai': np.int64(13008),
#  'demikian': np.int64(11872),
#  'ukuran': np.int64(47234),
#  'terlihat': np.int64(45530),
#  'apabila': np.int64(4529),
#  'balik': np.int64(5852),
#  'pemasangan': np.int64(34580),
#  'berikatan': np.int64(6939),
#  'komplementer': np.int64(24542),
#  'susunan': np.int64(44129),
#  'ia': np.int64(20041),
#  'digabung': np.int64(12595),
#  'kembali': np.int64(23400),
#  'relatif': np.int64(38789),
#  'ditarik': np.int64(13629),
#  'terbuka': np.int64(45324),
#  'baik': np.int64(5758),
#  'gaya': np.int64(17260),
#  'mekanika': np.int64(28236),
#  'maupun': np.int64(27981),
#  'temperatur': np.int64(45137),
#  'tinggi': np.int64(46094),
#  'kritikal': np.int64(24972),
#  'keseluruhan': np.int64(23762),
#  'perlu': np.int64(35870),
#  'kotak': np.int64(24853),
#  'promotor': np.int64(37482),
#  'cenderung': np.int64(9531),
#  'kandungan': np.int64(22466),
#  'at': np.int64(5187),
#  'stabilitas': np.int64(43245),
#  'berbagai': np.int64(6725),
#  'cara': np.int64(9218),
#  'umumnya': np.int64(47323),
#  'berdasarkan': np.int64(6807),
#  'lebur': np.int64(25822),
#  'nilai': np.int64(32326),
#  'sub': np.int64(43615),
#  '50': np.int64(1939),
#  'terurai': np.int64(45728),
#  'tunggal': np.int64(46958),
#  'bergantung': np.int64(6877),
#  'kekuatan': np.int64(23265),
#  'ionik': np.int64(20940),
#  'konsentrasi': np.int64(24645),
#  'terpisah': np.int64(45609),
#  'berdiri': np.int64(6825),
#  'sendiri': np.int64(41312),
#  'stabil': np.int64(43243),
#  'sense': np.int64(41352),
#  'sekuens': np.int64(41093),
#  'kopi': np.int64(24763),
#  'duta': np.int64(14349),
#  'prokariota': np.int64(37457),
#  'eukariota': np.int64(15425),
#  'diproduksi': np.int64(13243),
#  'tidaklah': np.int64(45993),
#  'jelas': np.int64(21624),
#  'diajukan': np.int64(12225),
#  'regulasi': np.int64(38713),
#  'ekspresi': np.int64(14748),
#  'gen': np.int64(17356),
#  'plasmid': np.int64(36631),
#  'kabur': np.int64(22190),
#  'tumpang': np.int64(46936),
#  'tindih': np.int64(46088),
#  'tugas': np.int64(46877),
#  'dibaca': np.int64(12318),
#  'kemungkinan': np.int64(23456),
#  'meningkatkan': np.int64(29688),
#  'jumlah': np.int64(22048),
#  'genom': np.int64(17421),
#  'kumparan': np.int64(25135),
#  'tali': np.int64(44604),
#  'kondisi': np.int64(24587),
#  'relaksasi': np.int64(38785),
#  'mengitari': np.int64(29549),
#  'jika': np.int64(21770),
#  'rapat': np.int64(38365),
#  'longgar': np.int64(26587),
#  'searah': np.int64(40824),
#  'dinamakan': np.int64(13009),
#  'positif': np.int64(36995),
#  'terlepas': np.int64(45526),
#  'negatif': np.int64(32018),
#  'alamiah': np.int64(3545),
#  'disebabkan': np.int64(13431),
#  'enzim': np.int64(15154),
#  'diperlukan': np.int64(13178),
#  'melepaskan': np.int64(28337),
#  'tegangan': np.int64(45009),
#  'dialami': np.int64(12240),
#  'alternatif': np.int64(3849),
#  'kita': np.int64(24207),
#  'temukan': np.int64(45165),
#  'antaranya': np.int64(4398),
#  'saja': np.int64(40098),
#  'diamati': np.int64(12256),
#  'langsung': np.int64(25551),
#  'fungsional': np.int64(16891),
#  'basis': np.int64(6175),
#  'buatan': np.int64(8592),
#  'disintesis': np.int64(13514),
#  'dimasukkan': np.int64(12963),
#  'analog': np.int64(4095),
#  'delapan': np.int64(11826),
#  'bernama': np.int64(7194),
#  'membelah': np.int64(28548),
#  'diri': np.int64(13338),
#  'kecuali': np.int64(23055),
#  'gamet': np.int64(17108),
#  'harus': np.int64(18875),
#  'disertai': np.int64(13481),
#  'supaya': np.int64(43962),
#  'turunan': np.int64(47033),
#  'genetik': np.int64(17396),
#  'dasarnya': np.int64(11539),
#  'memanfaatkan': np.int64(28455),
#  'fakta': np.int64(15769),
#  'konjugat': np.int64(24627),
#  'pasangannya': np.int64(34104),
#  'kata': np.int64(22760),
#  'lain': np.int64(25419),
#  'mengetahui': np.int64(29357),
#  'maka': np.int64(27208),
#  'dibentuk': np.int64(12369),
#  'mencoba': np.int64(28988),
#  'menjelaskan': np.int64(29735),
#  'bagaimana': np.int64(5698),
#  'paling': np.int64(33726),
#  'populer': np.int64(36943),
#  'menyatakan': np.int64(29903),
#  'masing': np.int64(27832),
#  'baru': np.int64(6140),
#  'diperoleh': np.int64(13180),
#  'akhir': np.int64(3428),
#  'sebelumnya': np.int64(40865),
#  'tersebut': np.int64(45648),
#  'bertindak': np.int64(7447),
#  'cetakan': np.int64(9613),
#  'memerlukan': np.int64(28675),
#  'pembantu': np.int64(34615),
#  'terpenting': np.int64(45597),
#  'nama': np.int64(31732),
#  'pembentukan': np.int64(34645),
#  'suatu': np.int64(43614),
#  'diawali': np.int64(12313),
#  'pembukaan': np.int64(34692),
#  'untaian': np.int64(47466),
#  'titik': np.int64(46171),
#  'dibantu': np.int64(12340),
#  'mengenali': np.int64(29335),
#  'mampu': np.int64(27358),
#  'membuka': np.int64(28625),
#  'setelah': np.int64(41615),
#  'cukup': np.int64(11100),
#  'terbentuk': np.int64(45308),
#  'akibat': np.int64(3437),
#  'masuk': np.int64(27873),
#  'sudah': np.int64(43705),
#  'lokal': np.int64(26546),
#  'berlangsung': np.int64(7119),
#  'pergeseran': np.int64(35757),
#  'mengikuti': np.int64(29499),
#  'membukanya': np.int64(28626),
#  'monomer': np.int64(30968),
#  'ditambahkan': np.int64(13607),
#  'sisi': np.int64(42451),
#  'kali': np.int64(22331),
#  'bergeser': np.int64(6896),
#  'berlanjut': np.int64(7121),
#  'sampai': np.int64(40259),
#  'benar': np.int64(6558),
#  'rumit': np.int64(39812),
#  'teliti': np.int64(45086),
#  'sintesis': np.int64(42403),
#  'mekanisme': np.int64(28238),
#  'mencegah': np.int64(28964),
#  'terjadinya': np.int64(45456),
#  'kesalahan': np.int64(23730),
#  'pemasukan': np.int64(34585),
#  'berakibat': np.int64(6672),
#  'fatal': np.int64(15895),
#  'penggunaan': np.int64(35203),
#  'teknologi': np.int64(45039),
#  'forensik': np.int64(16561),
#  'darah': np.int64(11476),
#  'sperma': np.int64(43099),
#  'kulit': np.int64(25109),
#  'liur': np.int64(26426),
#  'rambut': np.int64(38267),
#  'tersisa': np.int64(45676),
#  'tempat': np.int64(45128),
#  'kejadian': np.int64(23198),
#  'kejahatan': np.int64(23200),
#  'mengidentifikasi': np.int64(29490),
#  'tersangka': np.int64(45642),
#  'short': np.int64(41968),
#  'tandem': np.int64(44692),
#  'dibandingkan': np.int64(12331),
#  'dikembangkan': np.int64(12788),
#  '1984': np.int64(1308),
#  'alec': np.int64(3621),
#  'universitas': np.int64(47422),
#  'leicester': np.int64(25887),
#  'mendakwa': np.int64(29009),
#  'colin': np.int64(10382),
#  '1988': np.int64(1312),
#  'kasus': np.int64(22757),
#  'pembunuhan': np.int64(34700),
#  'leicestershire': np.int64(25888),
#  'yurisdiksi': np.int64(49591),
#  'membutuhkan': np.int64(28641),
#  'terdakwa': np.int64(45354),
#  'menyediakan': np.int64(29920),
#  'contoh': np.int64(10699),
#  'data': np.int64(11550),
#  'komputer': np.int64(24562),
#  'investigator': np.int64(20916),
#  'menyelesaikan': np.int64(29933),
#  'lama': np.int64(25468),
#  'pelanggar': np.int64(34456),
#  'terutama': np.int64(45733),
#  'pemerkosaan': np.int64(34738),
#  'orang': np.int64(33229),
#  'metode': np.int64(30286),
#  'teknik': np.int64(45033),
#  'tepercaya': np.int64(45237),
#  'seorang': np.int64(41399),
#  'pelaku': np.int64(34444),
#  'tetapi': np.int64(45759),
#  'sempurna': np.int64(41280),
#  'bila': np.int64(7706),
#  'terkontaminasi': np.int64(45500),
#  'komputasi': np.int64(24561),
#  'memainkan': np.int64(28427),
#  'peran': np.int64(35620),
#  'ilmu': np.int64(20307),
#  'masalah': np.int64(27807),
#  'riset': np.int64(39341),
#  'algoritme': np.int64(3688),
#  'pencarian': np.int64(34898),
#  'string': np.int64(43540),
#  'menemukan': np.int64(29126),
#  'huruf': np.int64(19936),
#  'dimotivasi': np.int64(12988),
#  'mencari': np.int64(28959),
#  'aplikasi': np.int64(4564),
#  'editor': np.int64(14556),
#  'text': np.int64(45784),
#  'bahkan': np.int64(5743),
#  'sederhana': np.int64(40924),
#  'mencukupi': np.int64(28995),
#  'menyebabkan': np.int64(29909),
#  'menunjukkan': np.int64(29843),
#  'mendekati': np.int64(29036),
#  'terburuk': np.int64(45331),
#  'karakter': np.int64(22575),
#  'berbeda': np.int64(6747),
#  'database': np.int64(11575),
#  'dipengaruhi': np.int64(13129),
#  'khusus': np.int64(24035),
#  'menaruh': np.int64(28935),
#  'memanipulasi': np.int64(28464),
#  'dikhususkan': np.int64(12814),
#  'dam': np.int64(11382),
#  'menangani': np.int64(28909),
#  'tantangan': np.int64(44761),
#  'teknis': np.int64(45035),
#  'unik': np.int64(47399),
#  'dihubungkan': np.int64(12678),
#  'operasi': np.int64(33161),
#  'kira': np.int64(24158),
#  'pola': np.int64(36795),
#  'homologi': np.int64(19653),
#  'sejarah': np.int64(41014),
#  'dimurnikan': np.int64(12997),
#  '1868': np.int64(1163),
#  'swiss': np.int64(44225),
#  'friedrich': np.int64(16781),
#  'jerman': np.int64(21704),
#  'menamainya': np.int64(28890),
#  'lokasinya': np.int64(26550),
#  'penelitian': np.int64(34999),
#  'peranan': np.int64(35622),
#  'dimulai': np.int64(12991),
#  'awal': np.int64(5469),
#  'abad': np.int64(2696),
#  '20': np.int64(1350),
#  'ditemukannya': np.int64(13664),
#  'postulat': np.int64(37022),
#  'mendel': np.int64(29040),
#  'dianggap': np.int64(12273),
#  'memungkinkan': np.int64(28850),
#  'pembawa': np.int64(34624),
#  'genetis': np.int64(17398),
#  'eksperimen': np.int64(14735),
#  'dekade': np.int64(11806),
#  '40': np.int64(1794),
#  'an': np.int64(4073),
#  'membuktikan': np.int64(28627),
#  'avery': np.int64(5432),
#  'rekan': np.int64(38758),
#  'rekannya': np.int64(38760),
#  'ekstrak': np.int64(14756),
#  'gagal': np.int64(16990),
#  'men': np.int64(28864),
#  'transform': np.int64(46576),
#  'dibiarkan': np.int64(12389),
#  'utuh': np.int64(47662),
#  'percobaan': np.int64(35689),
#  'hershey': np.int64(19269),
#  'chase': np.int64(9761),
#  'dilakukan': np.int64(12873),
#  'pencari': np.int64(34897),
#  'jejak': np.int64(21611),
#  'radioaktif': np.int64(38102),
#  'misteri': np.int64(30704),
#  'belum': np.int64(6550),
#  'terpecahkan': np.int64(45589),
#  'bagaimanakah': np.int64(5699),
#  'bertugas': np.int64(7463),
#  'persoalan': np.int64(36029),
#  'dijawab': np.int64(12737),
#  'koleganya': np.int64(24440),
#  'hasil': np.int64(18908),
#  'difraksi': np.int64(12590),
#  'sinar': np.int64(42301),
#  'maurice': np.int64(27986),
#  'wilkins': np.int64(48839),
#  'rosalind': np.int64(39612),
#  'franklin': np.int64(16705),
#  'mendefinisikan': np.int64(29033),
#  'kelompok': np.int64(23337),
#  'keempat': np.int64(23109),
#  'glukosa': np.int64(17797),
#  'berputar': np.int64(7292),
#  'hingga': np.int64(19452),
#  'ditentukan': np.int64(13670),
#  'diameter': np.int64(12259),
#  'bukan': np.int64(8686),
#  'melainkan': np.int64(28250),
#  'mendapatkan': np.int64(29017),
#  'hadiah': np.int64(18489),
#  'nobel': np.int64(32439),
#  'kedokteran': np.int64(23092),
#  '1962': np.int64(1280),
#  'penemuan': np.int64(35009),
#  'wafat': np.int64(48308),
#  'waktu': np.int64(48357),
#  'dianugerahi': np.int64(12286),
#  'konfirmasi': np.int64(24603),
#  'lewat': np.int64(26089),
#  'stahl': np.int64(43264),
#  '1958': np.int64(1273),
#  'referensi': np.int64(38646),
#  'kategori': np.int64(22783),
#  'molekular': np.int64(30892),
#  'muhammad': np.int64(31288),
#  'anwar': np.int64(4502),
#  'el': np.int64(14773),
#  'sadat': np.int64(39995),
#  'politikus': np.int64(36841),
#  'mesir': np.int64(30220),
#  'menjabat': np.int64(29701),
#  'presiden': np.int64(37254),
#  '15': np.int64(736),
#  'oktober': np.int64(33015),
#  '1970': np.int64(1289),
#  'pembunuhannya': np.int64(34701),
#  'perwira': np.int64(36137),
#  'tentara': np.int64(45209),
#  'fundamentalis': np.int64(16881),
#  '1981': np.int64(1305),
#  'senior': np.int64(41339),
#  'anggota': np.int64(4239),
#  'menggulingkan': np.int64(29412),
#  'raja': np.int64(38203),
#  'farouk': np.int64(15865),
#  'revolusi': np.int64(39129),
#  '1952': np.int64(1267),
#  'kepercayaan': np.int64(23587),
#  'dekat': np.int64(11809),
#  'gamal': np.int64(17083),
#  'abdel': np.int64(2721),
#  'nasser': np.int64(31863),
#  'dia': np.int64(12198),
#  'wakil': np.int64(48352),
#  'menggantikannya': np.int64(29382),
#  '1978': np.int64(1299),
#  'menachem': np.int64(28871),
#  'begin': np.int64(6430),
#  'perdana': np.int64(35699),
#  'menteri': np.int64(29794),
#  'israel': np.int64(21135),
#  'menandatangani': np.int64(28906),
#  'perjanjian': np.int64(35821),
#  'damai': np.int64(11386),
#  'amerika': np.int64(3975),
#  'serikat': np.int64(41525),
#  'jimmy': np.int64(21785),
#  'carter': np.int64(9312),
#  'mereka': np.int64(30119),
#  'diakui': np.int64(12234),
#  'perdamaian': np.int64(35698),
#  'sebelas': np.int64(40863),
#  'mengubah': np.int64(29603),
#  'lintasan': np.int64(26323),
#  'berangkat': np.int64(6695),
#  'prinsip': np.int64(37343),
#  'politik': np.int64(36838),
#  'ekonomi': np.int64(14694),
#  'melembagakan': np.int64(28327),
#  'sistem': np.int64(42462),
#  'multi': np.int64(31339),
#  'partai': np.int64(34048),
#  'meluncurkan': np.int64(28409),
#  'kebijakan': np.int64(22996),
#  'memimpin': np.int64(28695),
#  'perang': np.int64(35627),
#  'yom': np.int64(49440),
#  'kippur': np.int64(24154),
#  '1973': np.int64(1294),
#  'merebut': np.int64(30108),
#  'semenanjung': np.int64(41246),
#  'sinai': np.int64(42298),
#  'diduduki': np.int64(12536),
#  'sejak': np.int64(41012),
#  'hari': np.int64(18802),
#  '1967': np.int64(1285),
#  'menjadikannya': np.int64(29704),
#  'pahlawan': np.int64(33628),
#  'sementara': np.int64(41248),
#  'dunia': np.int64(14307),
#  'arab': np.int64(4660),
#  'luas': np.int64(26729),
#  'negosiasi': np.int64(32024),
#  'berpuncak': np.int64(7289),
#  'memenangkan': np.int64(28653),
#  'pemenang': np.int64(34715),
#  'muslim': np.int64(31492),
#  'meskipun': np.int64(30224),
#  'reaksi': np.int64(38519),
#  'mengakibatkan': np.int64(29201),
#  'kembalinya': np.int64(23403),
#  'menguntungkan': np.int64(29635),
#  'kalangan': np.int64(22312),
#  'ditolak': np.int64(13706),
#  'ikhwanul': np.int64(20256),
#  'muslimin': np.int64(31494),
#  'kaum': np.int64(22828),
#  'kiri': np.int64(24173),
#  'merasa': np.int64(30071),
#  'mengabaikan': np.int64(29169),
#  'upaya': np.int64(47491),
#  'memastikan': np.int64(28480),
#  'negara': np.int64(32014),
#  'palestina': np.int64(33716),
#  'militan': np.int64(30494),
#  'dipimpin': np.int64(13212),
#  'khalid': np.int64(23983),
#  'menembaki': np.int64(29113),
#  'senapan': np.int64(41297),
#  'otomatis': np.int64(33406),
#  'selama': np.int64(41114),
#  'parade': np.int64(33929),
#  'kairo': np.int64(22266),
#  'membunuhnya': np.int64(28634),
#  'latar': np.int64(25648),
#  'belakang': np.int64(6480),
#  'dilahirkan': np.int64(12870),
#  'mit': np.int64(30714),
#  'abu': np.int64(2801),
#  'al': np.int64(3531),
#  'kum': np.int64(25118),
#  'keluarga': np.int64(23348),
#  'sudan': np.int64(43707),
#  'miskin': np.int64(30684),
#  'saudara': np.int64(40564),
#  'laki': np.int64(25436),
#  'perempuan': np.int64(35726),
#  'ayahnya': np.int64(5507),
#  'ibunya': np.int64(20088),
#  'lakinya': np.int64(25437),
#  'kelak': np.int64(23279),
#  'pilot': np.int64(36457),
#  'terbunuh': np.int64(45328),
#  'lulus': np.int64(26801),
#  'akademi': np.int64(3388),
#  'militer': np.int64(30496),
#  'kerajaan': np.int64(23638),
#  '1938': np.int64(1248),
#  'ditempatkan': np.int64(13658),
#  'korps': np.int64(24812),
#  'isyarat': np.int64(21173),
#  'bergabung': np.int64(6869),
#  'gerakan': np.int64(17492),
#  'bertekad': np.int64(7420),
#  'membebaskan': np.int64(28539),
#  'kekuasaan': np.int64(23262),
#  'britania': np.int64(8487),
#  'raya': np.int64(38470),
#  'dipenjarakan': np.int64(13132),
#  'usaha': np.int64(47571),
#  'usahanya': np.int64(47573),
#  'bantuan': np.int64(5998),
#  'poros': np.int64(36954),
#  'mengusir': np.int64(29651),
#  'pasukan': np.int64(34174),
#  'pendudukan': np.int64(34986),
#  'ikut': np.int64(20272),
#  'serta': np.int64(41546),
#  'kudeta': np.int64(25078),
#  'meletus': np.int64(28345),
#  'diperintahkan': np.int64(13163),
#  'mengambil': np.int64(29226),
#  'alih': np.int64(3713),
#  'jaringan': np.int64(21496),
#  'radio': np.int64(38100),
#  'mengumumkan': np.int64(29621),
#  'pecahnya': np.int64(34348),
#  'kepada': np.int64(23541),
#  'rakyat': np.int64(38244),
#  '1964': np.int64(1282),
#  'memegang': np.int64(28648),
#  'jabatan': np.int64(21285),
#  'pemerintahan': np.int64(34735),
#  'dipilih': np.int64(13210),
#  'menduduki': np.int64(29078),
#  '1966': np.int64(1284),
#  'sekali': np.int64(41036),
#  'lagi': np.int64(25395),
#  '1969': np.int64(1287),
#  'meninggal': np.int64(29680),
#  'dilantik': np.int64(12884),
#  'bersama': np.int64(7307),
#  'hafez': np.int64(18515),
#  'assad': np.int64(5099),
#  'syria': np.int64(44337),
#  'melawan': np.int64(28297),
#  'dicaplok': np.int64(12434),
#  'krisis': np.int64(24955),
#  'terusan': np.int64(45731),
#  'suez': np.int64(43726),
#  '1956': np.int64(1271),
#  'pertempuran': np.int64(36079),
#  'masih': np.int64(27831),
#  'dipertentangkan': np.int64(13196),
#  'pihak': np.int64(36421),
#  'menang': np.int64(28908),
#  'kalah': np.int64(22307),
#  'camp': np.int64(9107),
#  'david': np.int64(11614),
#  'menetapkan': np.int64(29161),
#  'keberhasilan': np.int64(22984),
#  'moral': np.int64(31040),
#  'mengadakan': np.int64(29178),
#  'berikutnya': np.int64(6943),
#  'diprakarsai': np.int64(13238),
#  'henry': np.int64(19192),
#  'kissinger': np.int64(24204),
#  'memang': np.int64(28457),
#  'mengembalikan': np.int64(29320),
#  'wilayah': np.int64(48818),
#  'direbut': np.int64(13295),
#  'dataran': np.int64(11582),
#  'golan': np.int64(17864),
#  'meski': np.int64(30223),
#  'ramadhan': np.int64(38254),
#  'jerusalem': np.int64(21713),
#  'timur': np.int64(46081),
#  'mengatakan': np.int64(29270),
#  'dilupakan': np.int64(12942),
#  'kemarahan': np.int64(23383),
#  'plo': np.int64(36685),
#  'pergerakan': np.int64(35755),
#  'islam': np.int64(21096),
#  'kunjungannya': np.int64(25160),
#  'undangan': np.int64(47343),
#  '1977': np.int64(1298),
#  'kunjungan': np.int64(25159),
#  'perundingan': np.int64(36120),
#  'terciptalah': np.int64(45349),
#  'menerima': np.int64(29149),
#  'bagaimanapun': np.int64(5700),
#  'tindakan': np.int64(46086),
#  'ditentang': np.int64(13669),
#  'hebat': np.int64(19060),
#  'percaya': np.int64(35678),
#  'ancaman': np.int64(4130),
#  'memaksa': np.int64(28437),
#  'berunding': np.int64(7487),
#  'mengenai': np.int64(29331),
#  'signifikan': np.int64(42147),
#  'disamping': np.int64(13391),
#  'irak': np.int64(20982),
#  'saat': np.int64(39937),
#  'september': np.int64(41446),
#  'mengenakan': np.int64(29333),
#  'represif': np.int64(38948),
#  'organisasi': np.int64(33275),
#  'kumpulan': np.int64(25137),
#  'pelajar': np.int64(34436),
#  'koptik': np.int64(24770),
#  'dianggapnya': np.int64(12274),
#  'mengganggu': np.int64(29379),
#  'nasional': np.int64(31848),
#  'penangkapan': np.int64(34862),
#  'penahanan': np.int64(34825),
#  'dikecam': np.int64(12776),
#  'diseluruh': np.int64(13458),
#  'pelanggaran': np.int64(34457),
#  'ham': np.int64(18622),
#  'tindakannya': np.int64(46087),
#  'tewas': np.int64(45779),
#  'ditembak': np.int64(13651),
#  'jihad': np.int64(21767),
#  'berhaluan': np.int64(6916),
#  'keras': np.int64(23657),
#  'menentang': np.int64(29135),
#  'peristiwa': np.int64(35815),
#  'mubarak': np.int64(31255),
#  'catatan': np.int64(9376),
#  'kaki': np.int64(22299),
#  'kepala': np.int64(23548),
#  'dibunuh': np.int64(12418),
#  'person': np.int64(36030),
#  'of': np.int64(32927),
#  'the': np.int64(45831),
#  'year': np.int64(49346),
#  'pemimpin': np.int64(34757),
#  'dingin': np.int64(13029),
#  'tokoh': np.int64(46283),
#  'kolonel': np.int64(24455),
#  'arkeologi': np.int64(4836),
#  'kepurbakalaan': np.int64(23622),
#  'mempelajari': np.int64(28736),
#  'kebudayaan': np.int64(23010),
#  'umat': np.int64(47286),
#  'masa': np.int64(27799),
#  'lalu': np.int64(25465),
#  'sistematis': np.int64(42465),
#  'ditinggalkan': np.int64(13694),
#  'meliputi': np.int64(28369),
#  'dokumentasi': np.int64(13946),
#  'analisis': np.int64(4091),
#  'budaya': np.int64(8626),
#  'norma': np.int64(32543),
#  'kebiasaan': np.int64(22993),
#  'adat': np.int64(2939),
#  'interpretasi': np.int64(20843),
#  ...}

# %%
#melakukan fitting vectorizer pada data
tfidf_matrix = vectorizer.transform(df_cleaned['text_cleaned'])

# %%
# melhat representasi nilai sebuah token pada dokumen
token_idx = vectorizer.vocabulary_['dna'].item()
tfidf_matrix[0,token_idx]
# Out:
# np.float32(0.84020346)

# %% [markdown]
# ### 6.3 Simulasi Search and Retreival Sederhana
#
# Mencoba menemukan dokumen yang paling relevan berdasarkan query (kata kunci)

# %%
# query
query = 'prabowo gerindra subianto'

# %%
#melakukan tranformasi pada query (tokenisasi dan vektorisasi)
query_vec = vectorizer.transform([query])
query_vec
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float32'
# 	with 3 stored elements and shape (1, 50000)>

# %%
from sklearn.metrics.pairwise import cosine_similarity

#menghitung kemiripan query ke kumpulan dokumen
similarity = cosine_similarity(query_vec, tfidf_matrix)

# top 10 dokumen yang paling mirip
top_10_idx = similarity.flatten().argsort()[::-1][:10]

#menampilkan 10 dokumen yang paling mirip
result = df_cleaned.loc[top_10_idx, :]

# %%
result
# Out:
#        Unnamed: 0       id             timestamp  \
# 19045       19045   281001  2022-11-08T16:43:54Z
# 45658       45658  1632906  2022-11-05T05:36:28Z
# 19844       19844   297680  2022-11-05T09:38:04Z
# 49223       49223  1804693  2022-05-13T23:57:12Z
# 67816       67816  2791246  2022-11-10T22:08:12Z
# 64703       64703  2666062  2022-11-13T08:04:59Z
# 43927       43927  1497283  2022-11-12T22:04:39Z
# 38839       38839  1098211  2022-11-06T02:23:09Z
# 45402       45402  1610110  2022-10-15T09:03:45Z
# 67813       67813  2791117  2019-05-03T08:52:53Z
#
#                                                    title  \
# 19045                                   Prabowo Subianto
# 45658                                       Edhy Prabowo
# 19844                      Partai Gerakan Indonesia Raya
# 49223                    Daftar aksi Koalisi Merah Putih
# 67816  Hasil survei pemilihan umum Presiden Indonesia...
# 64703                      Koalisi Indonesia Adil Makmur
# 43927                                     Moekhlas Sidik
# 38839                                      Andre Rosiade
# 45402                                Koalisi Merah Putih
# 67813                   Kasus kebohongan Ratna Sarumpaet
#
#                                                     text  \
# 19045  [[Letnan Jenderal]] [[TNI]] ([[Purnawirawan|Pu...
# 45658  [[Doktor|Dr.]] '''Edhy Prabowo''', [[Sarjana E...
# 19844  '''Partai Gerakan Indonesia Raya''' ('''Gerind...
# 49223  Berikut ini adalah daftar aksi [[Koalisi Merah...
# 67816  Berikut adalah '''hasil survei pemilihan umum ...
# 64703  '''Koalisi Indonesia Adil Makmur''' adalah [[k...
# 43927  [[Laksamana Madya]] [[TNI]] ([[Purnawirawan|Pu...
# 38839  [[Haji (gelar)|H.]] '''Andre Rosiade''', [[Sar...
# 45402  '''Koalisi Merah Putih''' (sering disingkat ''...
# 67813  '''[[Ratna Sarumpaet]]''' adalah salah satu an...
#
#                                                 kategori  \
# 19045  [Pengusaha Indonesia, Pengusaha Jawa, Tokoh mi...
# 45658  [Tokoh dari Muara Enim, Politikus Indonesia, P...
# 19844  [Partai Gerakan Indonesia Raya,  , Partai poli...
# 49223                        [Tokoh Koalisi Merah Putih]
# 67816           [Pemilihan umum Presiden Indonesia 2014]
# 64703  [Koalisi partai politik di Indonesia, Adil Mak...
# 43927  [Tokoh Tentara Nasional Indonesia Angkatan Lau...
# 38839  [Politikus Partai Gerakan Indonesia Raya, Peng...
# 45402  [Koalisi partai politik di Indonesia, Merah Pu...
# 67813             [Indonesia dalam tahun 2018, Penipuan]
#
#                                             text_cleaned
# 19045  Letnan Jenderal TNI (Purn.) Haji (gelar)|H. ''...
# 45658  Doktor|Dr. '''Edhy Prabowo''', Sarjana Ekonomi...
# 19844  '''Partai Gerakan Indonesia Raya''' ('''Gerind...
# 49223  Berikut ini adalah daftar aksi Koalisi Merah P...
# 67816  Berikut adalah '''hasil survei pemilihan umum ...
# 64703  '''Koalisi Indonesia Adil Makmur''' adalah koa...
# 43927  Laksamana Madya TNI (Purnawirawan|Purn.) '''Mo...
# 38839  Haji (gelar)|H. '''Andre Rosiade''', Sarjana E...
# 45402  '''Koalisi Merah Putih''' (sering disingkat ''...
# 67813  '''Ratna Sarumpaet''' adalah salah satu anggot...
